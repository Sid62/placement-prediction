# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\siddh\Downloads\archive\placement.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['package'])

# %%
x=df.iloc[:,0]
y=df.iloc[:,-1]

# %%
x
# Out:
# 0      6.89
# 1      5.12
# 2      7.82
# 3      7.42
# 4      6.94
#        ...
# 195    6.93
# 196    5.89
# 197    7.21
# 198    7.63
# 199    6.22
# Name: cgpa, Length: 200, dtype: float64

# %%
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cgpa     200 non-null    float64
#  1   package  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
# 80     7.63
# 69     7.30
# 72     7.78
# 128    7.93
# 53     6.47
#        ...
# 68     7.56
# 75     6.97
# 42     5.95
# 152    7.37
# 107    6.33
# Name: cgpa, Length: 180, dtype: float64

# %%
x_test
# Out:
# 16     6.84
# 160    7.13
# 182    5.88
# 157    6.47
# 71     7.47
# 175    7.04
# 103    7.05
# 141    6.76
# 41     6.89
# 161    7.30
# 148    7.57
# 163    8.93
# 122    5.12
# 177    7.09
# 45     7.87
# 48     8.63
# 133    6.05
# 57     6.60
# 106    6.13
# 123    5.10
# Name: cgpa, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler= StandardScaler()

# %%
x_train = x_train.to_frame()

# Now apply scaling
x_train = scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 0.58344875],
#        [ 0.27734686],
#        [ 0.72258597],
#        [ 0.8617232 ],
#        [-0.49254577],
#        [-2.10653755],
#        [ 0.88027483],
#        [ 1.50175442],
#        [ 0.33300175],
#        [ 0.70403435],
#        [ 0.25879523],
#        [ 1.02868786],
#        [ 1.58523675],
#        [-1.03054303],
#        [ 1.89133864],
#        [ 0.1753129 ],
#        [-0.68733788],
#        [-0.86357836],
#        [-0.75226858],
#        [-0.26992621],
#        [ 0.55562131],
#        [ 0.25879523],
#        [-0.01947921],
#        [ 0.39793246],
#        [ 1.04723949],
#        [ 0.25879523],
#        [ 0.51851805],
#        [-1.46650632],
#        [-0.77082021],
#        [ 0.38865664],
#        [ 1.26985905],
#        [-0.79864766],
#        [ 0.87099901],
#        [-0.86357836],
#        [ 0.56489712],
#        [ 0.12893383],
#        [ 0.6112762 ],
#        [-0.0751341 ],
#        [ 0.33300175],
#        [-0.06585829],
#        [ 0.58344875],
#        [ 0.10110638],
#        [-0.23282295],
#        [ 1.09361857],
#        [-1.02126721],
#        [ 2.09540657],
#        [-0.98416395],
#        [-0.65951043],
#        [-1.50360958],
#        [-1.99522777],
#        [ 0.31445012],
#        [ 0.44431153],
#        [-0.60385555],
#        [ 1.1121702 ],
#        [ 0.71331016],
#        [ 0.57417294],
#        [ 1.06579112],
#        [ 1.52958186],
#        [ 0.30517431],
#        [-1.24388677],
#        [-0.97488814],
#        [-1.0769221 ],
#        [-0.23282295],
#        [-0.84502673],
#        [-1.29026584],
#        [-0.05658247],
#        [-1.0769221 ],
#        [ 1.21420416],
#        [ 2.14178564],
#        [ 0.19386453],
#        [ 2.00264842],
#        [-2.54250084],
#        [-1.75405658],
#        [-0.20499551],
#        [-0.1400648 ],
#        [-1.0769221 ],
#        [ 0.26807105],
#        [-0.05658247],
#        [-0.87285418],
#        [-0.45544251],
#        [ 0.1103822 ],
#        [ 1.15854927],
#        [ 1.90989027],
#        [-0.05658247],
#        [-0.36268436],
#        [-0.10296154],
#        [-0.65023462],
#        [-1.36447236],
#        [-0.72444114],
#        [ 0.81534412],
#        [-0.05658247],
#        [ 0.83389575],
#        [-0.6409588 ],
#        [-1.2624384 ],
#        [-0.81719929],
#        [-0.19571969],
#        [-1.55926447],
#        [-0.75226858],
#        [-0.34413273],
#        [ 0.23096779],
#        [ 0.93592972],
#        [ 1.46465116],
#        [ 0.12893383],
#        [-0.36268436],
#        [ 0.10110638],
#        [-0.06585829],
#        [-1.0769221 ],
#        [-1.0769221 ],
#        [-0.75226858],
#        [ 0.35155338],
#        [ 1.13072183],
#        [ 0.82461994],
#        [-1.46650632],
#        [ 0.3608292 ],
#        [ 0.16603709],
#        [ 1.33478975],
#        [ 0.63910364],
#        [ 1.33478975],
#        [-0.31630529],
#        [-0.93778488],
#        [-1.0119914 ],
#        [ 1.73364979],
#        [-0.83575092],
#        [ 0.82461994],
#        [-0.1400648 ],
#        [-1.12330118],
#        [ 0.84317157],
#        [-0.38123599],
#        [-1.77260821],
#        [-1.74478077],
#        [-0.61313136],
#        [-0.13078899],
#        [-0.83575092],
#        [-1.08619792],
#        [ 0.25879523],
#        [-2.05088266],
#        [ 1.18637672],
#        [-1.73550495],
#        [ 1.01941205],
#        [ 1.21420416],
#        [-1.64274681],
#        [-0.72444114],
#        [-0.43689088],
#        [ 0.13820964],
#        [ 0.77824086],
#        [ 0.18458872],
#        [-2.25495058],
#        [ 1.48320279],
#        [-0.72444114],
#        [ 1.79858049],
#        [ 0.75968923],
#        [-0.29775366],
#        [ 0.37010501],
#        [-0.53892484],
#        [ 1.12144601],
#        [-0.12151317],
#        [ 1.01013623],
#        [-0.06585829],
#        [-0.06585829],
#        [-0.25137458],
#        [ 0.07327894],
#        [ 2.20671635],
#        [-0.03803084],
#        [-1.31809329],
#        [-0.58530392],
#        [-1.41085143],
#        [ 0.84317157],
#        [ 1.25130742],
#        [-0.46471832],
#        [ 0.32372594],
#        [ 1.84495957],
#        [-0.94706069],
#        [ 0.6762069 ],
#        [ 0.29589849],
#        [ 2.39223264],
#        [ 0.51851805],
#        [-0.02875503],
#        [-0.97488814],
#        [ 0.34227757],
#        [-0.62240717]])

# %%
x_test = x_test.to_frame()
x_test=scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
clf=LinearRegression()

# %%
#model tranning
clf.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=clf.predict(x_test)

# %%
y_test
# Out:
# 16     2.35
# 160    2.93
# 182    2.08
# 157    2.70
# 71     3.34
# 175    3.50
# 103    3.00
# 141    3.18
# 41     2.70
# 161    3.33
# 148    3.40
# 163    3.91
# 122    2.01
# 177    3.64
# 45     3.58
# 48     4.09
# 133    2.58
# 57     1.94
# 106    2.19
# 123    2.30
# Name: package, dtype: float64

# %%
from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R2 Score:", r2)
# Out:
# Mean Squared Error: 0.11044409063509006
# R2 Score: 0.7316378906870935
